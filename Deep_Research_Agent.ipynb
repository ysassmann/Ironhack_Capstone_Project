# %%
# Load all necessary packages

import pandas as pd
import os
from typing import List, Dict
from pathlib import Path
from openai import AzureOpenAI
from langchain_openai import ChatOpenAI, OpenAIEmbeddings, AzureOpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader, TextLoader, PyPDFDirectoryLoader
from langchain_classic.agents import AgentExecutor, create_tool_calling_agent, create_react_agent, create_openai_tools_agent
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.tools import Tool
from dotenv import load_dotenv
import time
from tqdm import tqdm
# Out:
# WARNING:tensorflow:From c:\Users\yannik_sassmann\AppData\Local\Programs\Python\Python313\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
load_dotenv()
# Out:
# True

# %%
file_path =r"C:\Users\yannik_sassmann\Documents\YASA\Fortbildungen\Data_Science_Bootcamp\Final_Project\Ironhack_Capstone_Project\pdfs\giz"
documents_path=r"C:\Users\yannik_sassmann\Documents\YASA\Fortbildungen\Data_Science_Bootcamp\Final_Project\Ironhack_Capstone_Project\pdfs\giz"

# %%
class DeepResearchAgent:
    SYSTEM_PROMPT = """You are a Senior Development Cooperation Analyst specializing in evidence-based project design and institutional learning. You work for a ministry planning new sustainable development projects globally, and your role is to extract actionable, non-obvious lessons from past project documentation.

    CORE MISSION:
    Extract specific, contextual insights from past development cooperation projects that can meaningfully inform the critical review of new project proposals. Your insights must go beyond generic development wisdom to reveal nuanced patterns, context-specific success factors, and overlooked risks.

    RESEARCH PROTOCOL:

    1. INITIAL EXPLORATION (Use deep_search):
    - Cast a wide net to understand the landscape of similar projects
    - Identify patterns across multiple projects, countries, and sectors
    - Look for both successes AND failures - failures often teach more

    2. DEEP DIVE (Use search_documents or diverse_search):
    - Investigate specific mechanisms: WHY did something work or fail?
    - Identify contextual factors: political economy, timing, stakeholder dynamics
    - Look for implementation details, not just outcomes
    - Search for quantitative data, timelines, budget allocations

    3. CRITICAL SYNTHESIS:
    - Compare contradictory findings across different projects
    - Identify conditions under which similar approaches succeeded or failed
    - Distinguish correlation from causation
    - Note what the documents DON'T say (gaps in reporting, avoided topics)

    QUALITY STANDARDS FOR INSIGHTS:

    ✅ GOOD INSIGHTS (Aim for these):
    - "In 3 water projects in Sub-Saharan Africa (Tanzania 2018, Kenya 2019, Uganda 2020), community ownership was only sustained when local government budget allocations for maintenance were secured BEFORE project handover. Projects that relied on community fees alone saw 65% infrastructure failure within 2 years." [Source: X, Page Y]

    - "Agricultural training programs in South Asia showed 40% higher adoption rates when conducted by local farmer-trainers rather than external consultants, BUT only in communities with existing farmer cooperatives. In communities without cooperatives, external trainers performed better." [Source: X, Page Y]

    ❌ POOR INSIGHTS (Avoid these):
    - "Stakeholder engagement is important for project success"
    - "Local ownership matters"
    - "Context is crucial"
    - "Monitoring and evaluation should be robust"

    INSIGHT CHARACTERISTICS YOU MUST AIM FOR:

    1. **Specificity**: Include numbers, timeframes, locations, project names
    2. **Conditionality**: "X worked when Y was true, but failed when Z"
    3. **Mechanisms**: Explain HOW and WHY, not just WHAT
    4. **Actionability**: Clear implications for proposal reviewers
    5. **Evidence-based**: Always cite specific sources with page numbers
    6. **Non-obvious**: Would surprise an experienced development practitioner

    ANALYTICAL FRAMEWORK - Always consider:

    - **Design Phase**: What assumptions proved wrong? What baseline data was missing?
    - **Implementation**: What institutional bottlenecks emerged? Which partnerships worked?
    - **Sustainability**: What happened after project end? What cost structures proved unrealistic?
    - **Context**: Political economy factors, timing, cultural dynamics, institutional capacity
    - **Scale**: What worked at pilot but failed at scale? Or vice versa?
    - **Unintended Consequences**: Negative spillovers, market distortions, dependency creation

   SEARCH STRATEGY:

    Phase 1 - LANDSCAPE MAPPING:
    - Use deep_search to understand the topic broadly
    - Use compare_projects if looking at different regions/approaches

    Phase 2 - CRITICAL ANALYSIS:
    - Use find_failure_cases to understand what went wrong
    - Use find_longterm_outcomes to check sustainability

    Phase 3 - EVIDENCE GATHERING:
    - Use analyze_context_factors to understand WHY
    - Use find_implementation_details to understand HOW

    Phase 4 - RISK ASSESSMENT:
    - Use identify_risk_patterns to flag concerns for new proposals

    Phase 5 - TARGETED FOLLOW-UP:
    - Use search_documents for specific clarifications

    OUTPUT FORMAT:

    Structure your response as:

    **Key Findings:**
    [3-5 specific, actionable insights with full citations]

    **Critical Success Factors:**
    [What conditions needed to be in place - be specific about sequence, timing, institutional requirements]

    **Common Failure Modes:**
    [What went wrong and why - include early warning signs]

    **Red Flags for Proposal Review:**
    [Specific things to look for in new proposals based on past failures]

    **Evidence Gaps:**
    [What information you couldn't find that would be valuable]

    ** Citation section:**
    [Include a ### Sources section. Format each source as:
    [n] Titel (Erscheinungsdatum) | Filename | Page X
    Use ONLY values returned by the search tools. Never include URLs.]


    CRITICAL GUIDELINES:
    - Prioritize project evaluations, mid-term reviews, and lessons-learned documents
    - Value negative findings as much as positive ones
    - If you find contradictory evidence, present both sides with context
    - Distinguish between project outputs (delivered) and outcomes (sustained change)
    - Be skeptical of self-reported success without independent verification
    - Always consider the political economy: Who benefited? Who lost? What power dynamics existed?
    - Flag when sample sizes are small or evidence is thin
    - Note when "success" was measured too early (before sustainability could be assessed)

    EVIDENCE DISCIPLINE:
    - If your search results contain no relevant evidence for a claim, you MUST write: 'No evidence found in available documents for this claim.'
    - Never bridge evidence gaps with general development knowledge
    - If fewer than 2 sources support a finding, explicitly flag it as: '[Single source — treat with caution]'
    - Never extrapolate from one country/sector to another without explicitly stating you are doing so and flagging it as an inference, not a finding
    
    HARD LIMITS:
    - Use a maximum of 4 search tool calls per research question
    - After 3 tool calls, assess whether you have sufficient evidence to synthesize
    - If yes: stop searching and write your final answer immediately
    - If no: use 1 more targeted tool call, then synthesize regardless
    - Never use more than 4 tool calls — always reserve the final step for synthesis
    - Stop immediately when your last 2 searches returned similar information

    CITATION RULES (strictly enforced):
    - Only cite sources that appeared in your search tool results
    - Use the exact filename and page number returned by the tools
    - Never invent, guess, or supplement with sources from your training knowledge
    - If the document name is unclear, write: [Source: <filename>, Page: <page>]
    - Never include URLs unless they were explicitly present in the retrieved text
    - If evidence is insufficient, state: 'Insufficient evidence found in available documents

    TONE:
    Professional, analytical, constructively critical. Do not use abbreviations. Always write out abbreviations in full. You serve the ministry's learning mission, not project advocacy. Your job is to prevent repeating past mistakes and amplify proven approaches."""

    def __init__(self, persist_directory: str = "./chroma_db", documents_path: str = None):
        """
        Initialize the deep research agent.
        
        Args:
            documents_path: Path to a directory containing PDF files
            persist_directory: Where to store the vector database
        """
        
        # Using GPT-5
        self.llm = ChatOpenAI(model="gpt-5",
                              base_url="https://bootcampai.openai.azure.com/openai/v1/",
                              temperature = 0,
                              api_key=os.environ["OPENAI_AZURE_API_KEY"])
        
        
        # Create/load vector store
        # Check if vector store already exists
        if os.path.exists(persist_directory):
            print(f"✓ Found existing vector store at {persist_directory}")
            # Initialize embeddings (needed for Chroma to work)
            embeddings = OpenAIEmbeddings(
                model="text-embedding-3-large",
                base_url="https://bootcampai.openai.azure.com/openai/v1/",
                api_key=os.environ["OPENAI_AZURE_API_KEY"]
            )
            # Load existing vector store directly
            self.vectorstore = Chroma(
                persist_directory=persist_directory,
                embedding_function=embeddings
            )
            print("✓ Vector store loaded successfully!\n")
        else:
            # Vector store doesn't exist, create it
            if documents_path is None:
                raise ValueError(
                    f"Vector store not found at {persist_directory} and no documents_path provided. "
                    "Please provide documents_path to create the vector store."
                )
            print(f"Vector store not found. Creating new one from {documents_path}...")
            vector_store_creator = VectorStoreCreator(
                documents_path=documents_path,
                persist_directory=persist_directory
            )
            self.vectorstore = vector_store_creator.vectorstore
            print("✓ Vector store created!\n")


        # Create tools
        self.tools = self._create_tools()
        
        # Create agent
        self.agent_executor = self._create_agent()
    
    def _format_results(self, docs: List, prefix: str = "RESULTS") -> str:
        """Format search results consistently."""
        if not docs:
            return "No relevant documents found."
            
        results = [f"=== {prefix} ===\n",
                  "⚠️ ONLY cite sources listed below. Do not add external sources.\n"]
        for i, doc in enumerate(docs, 1):
            source = doc.metadata.get('source', 'Unknown')
            filename = os.path.basename(source)
            page = doc.metadata.get('page', 'N/A')
            results.append(
                f"\n[CITABLE SOURCE {i}]\n"
                f"  Filename: {filename}\n"
                f"  Page: {page}\n"
                f"  Content: {doc.page_content}\n"
                f"  ⚠️ No URL available for this source.\n"
        )
        return "\n".join(results)

    def _create_tools(self) -> List[Tool]:
        """Create tools for the agent."""
        
        def search_documents(query: str) -> str:
            docs = self.vectorstore.similarity_search(query, k=8)
            return self._format_results(docs, prefix="SEARCH RESULT")
        
        def deep_search(query: str) -> str:
            """Perform a deep search by generating multiple query variations."""
            variations_prompt = f"""Given this research question: "{query}"

            Generate 6 search queries to gather comprehensive information.
            IMPORTANT: Your document database contains documents in English, German, and French.
            Generate 2 queries in English, 2 in German, and 2 in French covering different aspects.

            Format as a numbered list:
            1. [English query 1]
            2. [English query 2]
            3. [German query 1]
            4. [German query 2]
            5. [French query 1]
            6. [French query 2]"""
            
            response = self.llm.invoke(variations_prompt)
            queries = [line.split('. ', 1)[1] for line in response.content.split('\n') 
                    if line.strip() and line[0].isdigit()]
            
            all_queries = [query] + queries[:6]
            
            all_results = {}
            for q in all_queries:
                docs = self.vectorstore.similarity_search(q, k=8)
                for doc in docs:
                    all_results[doc.page_content] = doc
            
            return self._format_results(list(all_results.values())[:15], prefix="DEEP SEARCH RESULTS")
        
        def compare_projects(query: str) -> str:
            """
            Compare similar projects across different contexts to identify 
            what worked where and why. Useful for finding patterns and 
            context-specific success factors.
            
            Example: "Compare water projects in East Africa vs West Africa"
            """
            comparison_prompt = f"""Given this comparison request: "{query}"

            Generate 4 search queries to compare projects effectively:
            1. A query for the first group/context
            2. A query for the second group/context  
            3. A query for common challenges across both
            4. A query for divergent outcomes/approaches

            Format as:
            1. [query 1]
            2. [query 2]
            3. [query 3]
            4. [query 4]"""

            response = self.llm.invoke(comparison_prompt)
            queries = [line.split('. ', 1)[1] for line in response.content.split('\n') 
                    if line.strip() and line[0].isdigit()]
            
            all_results = {}
            for q in queries[:4]:
                docs = self.vectorstore.similarity_search(q, k=8)
                for doc in docs:
                    all_results[doc.page_content] = doc
            
            return self._format_results(list(all_results.values())[:15], prefix="COMPARATIVE ANALYSIS")

        def find_failure_cases(query: str) -> str:
            """
            Specifically search for project failures, challenges, problems,
            and lessons learned from negative outcomes. Critical for learning
            what NOT to do.
            
            Example: "What caused agricultural projects to fail in the Sahel?"
            """
            failure_keywords = [
                f"{query} failure discontinued abandoned",                    # English
                f"{query} challenges problems obstacles",                     # English
                f"{query} Herausforderungen Probleme gescheitert abgebrochen", # German
                f"{query} Nachhaltigkeit Risiken Schwierigkeiten",            # German
                f"{query} défis problèmes échec abandonné",                   # French
                f"{query} durabilité risques difficultés",                    # French
            ]
            
            all_results = {}
            for fail_query in failure_keywords:
                docs = self.vectorstore.similarity_search(fail_query, k=8)
                for doc in docs:
                    content_lower = doc.page_content.lower()
                    if any(term in content_lower for term in 
                        ['fail', 'challenge', 'problem', 'difficult', 'unsustainable', 
                            'abandon', 'discontinue', 'not work', 'ineffective']):
                        all_results[doc.page_content] = doc
            
            return self._format_results(list(all_results.values())[:12], prefix="FAILURE CASES")

        def find_longterm_outcomes(query: str) -> str:
            """
            Search for long-term sustainability outcomes, post-project results,
            and what happened after project completion. Essential for understanding
            true impact vs. short-term outputs.
            
            Example: "What happened to health clinics 3 years after project end?"
            """
            temporal_queries = [
                f"{query} post-project sustainability long-term outcomes",
                f"{query} after completion follow-up years later",
                f"{query} maintained discontinued abandoned funding"
            ]
            
            all_results = {}
            for temp_query in temporal_queries:
                docs = self.vectorstore.similarity_search(temp_query, k=8)
                for doc in docs:
                    all_results[doc.page_content] = doc
            
            return self._format_results(list(all_results.values())[:15], 
                                    prefix="LONG-TERM OUTCOMES")

        def analyze_context_factors(query: str) -> str:
            """
            Search for political economy, institutional capacity, cultural factors,
            and contextual conditions that influenced project success/failure.
            
            Example: "What political factors affected governance projects in Myanmar?"
            """
            context_queries = [
                f"{query} political economy stakeholders",
                f"{query} institutional capacity governance",
                f"{query} cultural social norms",
                f"{query} enabling environment constraints",
                f"{query} local context conditions"
            ]
            
            all_results = {}
            for ctx_query in context_queries:
                docs = self.vectorstore.similarity_search(ctx_query, k=8)
                for doc in docs:
                    all_results[doc.page_content] = doc
            
            return self._format_results(list(all_results.values())[:15], 
                                        prefix="CONTEXTUAL FACTORS")

        def identify_risk_patterns(query: str) -> str:
            """
            Find early warning signs, risk factors, and red flags from past projects.
            Use to identify what to watch out for in new proposals.
            
            Example: "What were early warning signs of project delays in infrastructure?"
            """
            risk_queries = [
                f"{query} risks delays bottlenecks obstacles",
                f"{query} assumptions proved wrong underestimated",
                f"{query} early warning signs indicators red flags"
            ]
            
            all_results = {}
            for risk_query in risk_queries:
                docs = self.vectorstore.similarity_search(risk_query, k=8)
                for doc in docs:
                    all_results[doc.page_content] = doc
            
            return self._format_results(list(all_results.values())[:15], 
                                    prefix="RISK PATTERNS & RED FLAGS")

        def find_implementation_details(query: str) -> str:
            """
            Search for HOW things were implemented: partnerships, management structures,
            procurement, staffing, training approaches. The mechanics that made things work.
            
            Example: "How were community health workers recruited and trained in Ethiopia?"
            """
            implementation_queries = [
                f"{query} implementation approach partnership coordination",
                f"{query} procurement management training capacity building",
                f"{query} monitoring supervision quality control staffing"
            ]

            all_results = {}
            for impl_query in implementation_queries:
                docs = self.vectorstore.similarity_search(impl_query, k=8)
                for doc in docs:
                    all_results[doc.page_content] = doc
            
            return self._format_results(list(all_results.values())[:15], 
                                    prefix="IMPLEMENTATION DETAILS")


        return [
            # Core search
            Tool(
                name="search_documents",
                func=search_documents,
                description="Quick search for specific information or follow-up queries."
            ),
            Tool(
                name="deep_search",
                func=deep_search,
                description="Comprehensive multi-angle search. Use first for new topics."
            ),
            
            # Comparative & analytical
            Tool(
                name="compare_projects",
                func=compare_projects,
                description="Compare similar projects across contexts to identify patterns and context-specific factors."
            ),
            Tool(
                name="find_failure_cases",
                func=find_failure_cases,
                description="Find project failures, challenges, and negative outcomes. Critical for learning what to avoid."
            ),
            
            # Temporal analysis
            Tool(
                name="find_longterm_outcomes",
                func=find_longterm_outcomes,
                description="Find post-project sustainability and long-term results. Essential for true impact assessment."
            ),
            
            # Context & risks
            Tool(
                name="analyze_context_factors",
                func=analyze_context_factors,
                description="Find political economy, institutional, and cultural factors that influenced outcomes."
            ),
            Tool(
                name="identify_risk_patterns",
                func=identify_risk_patterns,
                description="Identify early warning signs and red flags from past projects."
            ),
            
            # Implementation
            Tool(
                name="find_implementation_details",
                func=find_implementation_details,
                description="Find HOW things were implemented: partnerships, training, management approaches."
            ),
        ]
    
    def _create_agent(self) -> AgentExecutor:
        """Create the research agent."""
        
        prompt = ChatPromptTemplate.from_messages([
    ("system", self.SYSTEM_PROMPT),
            ("human", "{input}"),
            MessagesPlaceholder(variable_name="agent_scratchpad"),
        ])
        
        agent = create_openai_tools_agent(
            llm=self.llm,
            tools=self.tools,
            prompt=prompt
        )
        
        return AgentExecutor(
            agent=agent,
            tools=self.tools,
            verbose=False, # Set to True to show reasoning
            max_iterations=8, # Beyond 5 iterations, gains were negligible despite significant increases in token consumption
            return_intermediate_steps=True, # Keep True to see tool calls
            early_stopping_method="generate" # Forces a final answer when limit is hit
        )
    
    def _validate_citations(self, response: str) -> str:
        import re
        urls = re.findall(r'https?://\S+', response)
        if urls:
            # Strip the hallucinated URLs from the response
            cleaned = re.sub(r'\s*https?://\S+', '', response)
            warning = (
                "\n\n---\n"
                "⚠️ Note: URL references were removed from this response. "
                "All citations refer exclusively to documents in the GIZ project database. "
                f"({len(urls)} URL(s) suppressed)"
            )
            return cleaned + warning
        return response

    def research(self, question: str) -> Dict:
        result = self.agent_executor.invoke({"input": question})
        result["output"] = self._validate_citations(result["output"])
        return result

# %%
# Example usage
if __name__ == "__main__":

    # Path to chroma db
    persist_directory = "./chroma_db"
    # documents_path = "C:\Users\yannik_sassmann\Documents\YASA\Fortbildungen\Data_Science_Bootcamp\Final_Project\Ironhack_Capstone_Project\pdfs\giz"

    # Initialize agent
    print("Initializing Deep Research Agent...")
    agent = DeepResearchAgent(persist_directory=persist_directory)
    print("Agent ready!\n")

    # Conduct research
    while True:
        question = input("\nYour question (or 'quit' to exit): ")
        if question.lower() in ['quit', 'exit', 'q']:
            break
        
        print(f"\n{'='*80}")
        print(f"RESEARCHING: {question}")
        print(f"{'='*80}\n")
        
        result = agent.research(question)
    
        print(f"\n{'='*80}")
        print(f"RESEARCH QUESTION: {question}")
        print(f"{'='*80}\n")
        
        result = agent.research(question)
        
        print(f"\n{'='*80}")
        print("FINAL ANSWER:")
        print(f"{'='*80}\n")
        print(result['output'])
# Out:
# Initializing Deep Research Agent...
# ✓ Found existing vector store at ./chroma_db
# ✓ Vector store loaded successfully!
#
# Agent ready!
#
#
# ================================================================================
# RESEARCHING: I have to review a project proposal for an egovernment project, i.e. digital transformation in the public sector in Africa. What learnings should I implement? What do I need to be aware off?
# ================================================================================
#
#
# ================================================================================
# RESEARCH QUESTION: I have to review a project proposal for an egovernment project, i.e. digital transformation in the public sector in Africa. What learnings should I implement? What do I need to be aware off?
# ================================================================================
#
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
#
# Key Findings:
# - Consolidating fragmented government web portals dramatically reduced maintenance burden and security risks in Rwanda. RISA reported moving from more than 200 siloed institutional websites—each with separate maintenance and higher hacking exposure—to a multitenant platform where “the work previously done by 200 can now be done by very few people.” A later evaluation found over 150 sites integrated and visually harmonised under the unified gov.rw web presence. Implication: proposals should prioritise platform consolidation over building new standalone portals, and include a centralized operations team and budgeting for ongoing maintenance and security hardening. [Sources: 2022-08_2017.2024.2_en.pdf, Page 42; 2025-12_2020.2091.5_en.pdf, Page 69]
#
# - Government-aligned digital solutions (co-developed to match specific departmental workflows) had high sustainability prospects when maintenance and financing plans were defined, open-source software was used to avoid high costs, and local companies were engaged for reasonably priced support. In contrast, donor-driven interventions not anchored in a clear governmental approach showed fickle ownership and weaker durability. Implication: require formal adoption by the implementing ministry, a signed operations and maintenance plan with budget lines, open-source or standards-based components to avoid lock-in, and a local maintenance procurement strategy. [Sources: 2022-08_2017.2024.2_en.pdf, Page 56; 2025-12_2020.2091.5_en.pdf, Page 69]
#
# - Training and innovation centers did not sustain impact when designed as one-off activities without device access or a viable host-institution model. In Rwanda, digital skills trainings were criticised as too episodic, with many trainees lacking smartphones to use the skills. The Digital Transformation Center had “no business case… not designed based on these parameters,” and was unlikely to be taken over by RISA given stretched capacity and shifting government priorities post-Covid. Implication: include device-access strategies (e.g., vouchers or pooled procurement), multi-session mentoring and on-the-job coaching, and an explicit financial and governance model for any hubs (fees, budget commitments, service contracts), plus senior management decisions to institutionalise training-of-trainers. [Sources: 2025-12_2020.2091.5_en.pdf, Page 67; 2022-08_2017.2024.2_en.pdf, Pages 55–57]
#
# - Monitoring and evaluation needs to be designed for intermittent connectivity and scarce secondary data. A pan-African digital project switched to Excel-based monitoring to accommodate stakeholders’ connectivity constraints, set indicators with zero baselines for new activities, and used an external monitoring expert. Implication: require offline-capable M&E workflows, realistic baseline strategies for new services, and explicit plans for data collection where national statistics are limited. [Single source — treat with caution] [Source: 2025-02_2019.2336.6_en.pdf, Page 26]
#
# - Ambitious cross-border digital outcomes failed to materialise without foundational systems (payments, logistics, postal reliability). Despite strategies and blueprints, no significant increase in cross-border e-commerce was recorded due to barriers in customs, e-payments, logistics; postal reliability scores were low (Kenya 27/100; Rwanda 30/100). Implication: proposals promising regional interoperability or cross-border services must incorporate dependencies and sequencing (payments, customs integration, logistics addressing) or limit scope to domestic services initially. [Single source — treat with caution] [Source: 2025-02_2019.2336.6_en.pdf, Page 21]
#
# Critical Success Factors:
# - Government ownership and integration: Align solutions tightly with the mandates and daily workflows of the responsible entities; secure a formal adoption decision and integration into “business-as-usual” processes before rollout. [2025-12_2020.2091.5_en.pdf, Page 69; 2022-08_2017.2024.2_en.pdf, Page 56]
# - Platform architecture and consolidation: Design for shared components (multitenant architecture, common identity and access, shared content management) to reduce maintenance overhead and attack surface. Establish a centralized operations and security team with clear responsibilities. [2022-08_2017.2024.2_en.pdf, Page 42]
# - Cost containment and maintenance: Use open-source or standards-based software to avoid high licensing and vendor lock-in; pre-arrange maintenance contracts with local firms and create financing plans. [2022-08_2017.2024.2_en.pdf, Page 56]
# - Capacity development that sticks: Complement classroom trainings with on-the-job coaching, mentoring, and “train-the-trainer” approaches anchored by senior management decisions and time allocation; ensure device access for trainees to apply skills. [2025-12_2020.2091.5_en.pdf, Page 67; 2022-08_2017.2024.2_en.pdf, Page 55]
# - Enabling environment and continuity: Projects benefit when there is consistent, high-level commitment to digital transformation and a relatively stable civil service to carry reforms forward. Factor in political economy shifts (e.g., revenue constraints post-crisis) that can re-prioritize agendas. [2025-12_2020.2091.5_en.pdf, Page 69; 2022-08_2017.2024.2_en.pdf, Page 56–57]
#
# Common Failure Modes:
# - Siloed development: Multiple uncoordinated websites and applications across ministries causing duplicated maintenance, weak security, and higher risk of content being hacked. Early warning sign: proposals with many separate portals per institution and no consolidation plan. [2022-08_2017.2024.2_en.pdf, Page 42]
# - Donor-driven agendas without institutional anchoring: Solutions perceived as externally driven rather than part of a coherent government approach; results fade after donor exit. Early warning sign: absence of formal government adoption decisions and budget commitments. [2025-12_2020.2091.5_en.pdf, Page 69]
# - Skills that do not translate into use: One-off trainings delivered without ongoing mentorship, institutional replication mechanisms, or device access lead to low sustained application. Early warning sign: training plans with no follow-on coaching or device strategy. [2025-12_2020.2091.5_en.pdf, Page 67; 2022-08_2017.2024.2_en.pdf, Page 55]
# - Innovation centers without a business or budget model: Hubs relying on donor funding and lacking host-institution capacity or revenue plans stall after projects end. Early warning sign: “Blueprint” centers with no O&M financing or defined service model. [2022-08_2017.2024.2_en.pdf, Pages 56–57]
# - Activities that require ongoing funding (hackathons, networks, chatbot maintenance) are fragile when recurring resources are not secured. Early warning sign: reliance on event-centric outputs without medium-term financing arrangements. [2025-07_2019.2010.7_en.pdf, Pages 86–87]
#
# Red Flags for Proposal Review:
# - Multiple new portals or apps proposed without a consolidation strategy, unified design system, or central operations and security plan.
# - No signed government decision to adopt and budget for O&M; maintenance and financing described only for the project period.
# - Proprietary stack with unclear interoperability standards and no local maintenance plan; absence of open-source or standards-based components to manage long-term costs.
# - Training components presented as short workshops without mentoring, “train-the-trainer,” or device access for target groups.
# - Establishment of an innovation hub or center with no revenue model, host-institution capacity assessment, or long-term financing plan.
# - Overambitious cross-border service claims that do not address payments, customs, logistics, or postal reliability; no staged domestic-first approach.
# - M&E plans that assume constant connectivity or lack realistic baseline strategies; reliance on online-only tools in low-connectivity settings. [Single source — treat with caution for M&E] [2025-02_2019.2336.6_en.pdf, Page 26]
# - Signals of risk-averse civil service and missing senior management decisions to institutionalize new practices (e.g., training-of-trainers). [2025-12_2020.2091.5_en.pdf, Page 67]
#
# Evidence Gaps:
# - No detailed cost comparisons quantifying maintenance savings from consolidation (e.g., staff time, security incident rates, budget changes).
# - Limited visibility on procurement approaches, vendor management, and interoperability frameworks for core government platforms (digital identity, payments, data exchange).
# - Sparse quantitative evidence on post-project service usage and user satisfaction over multi-year horizons.
# - Limited budget data specifying long-term O&M financing lines within government Medium-Term Expenditure Frameworks.
# - No detailed evaluations of data protection and accessibility compliance in implemented platforms (noted as a future consideration, but not evidenced).
#
# ### Sources
# [1] Central project evaluation – Digital Solutions for Sustainable Development, Rwanda; Evaluation Report (2022-08) | 2022-08_2017.2024.2_en.pdf | Page 42
#
# [2] Central project evaluation – Digital Solutions for Sustainable Development II, Rwanda; Evaluation Report (2025-12) | 2025-12_2020.2091.5_en.pdf | Page 69
#
# [3] Central project evaluation – Digital Solutions for Sustainable Development, Rwanda; Evaluation Report (2022-08) | 2022-08_2017.2024.2_en.pdf | Page 56
#
# [4] Central project evaluation – Digital Solutions for Sustainable Development II, Rwanda; Evaluation Report (2025-12) | 2025-12_2020.2091.5_en.pdf | Page 67
#
# [5] Central project evaluation – Digital Solutions for Sustainable Development, Rwanda; Evaluation Report (2022-08) | 2022-08_2017.2024.2_en.pdf | Pages 55–57
#
# [6] Central project evaluation – Sector Programme International Digital Policy for Sustainable Development, global project (2025-07) | 2025-07_2019.2010.7_en.pdf | Pages 86–87
#
# [7] Central project evaluation – Pan-African E-Commerce Initiative; Evaluation Report (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 26
#
# [8] Central project evaluation – Pan-African E-Commerce Initiative; Evaluation Report (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 21
#
# ================================================================================
# RESEARCHING: RESEARCH QUESTION: I have to review a project proposal for a digital transformation project in the private sector in Africa. What learnings should I implement? What do I need to be aware off?
# ================================================================================
#
#
# ================================================================================
# RESEARCH QUESTION: RESEARCH QUESTION: I have to review a project proposal for a digital transformation project in the private sector in Africa. What learnings should I implement? What do I need to be aware off?
# ================================================================================
#
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
#
# Key Findings:
# - Cross-border e-commerce ambitions were routinely overestimated unless payment and logistics constraints were explicitly addressed. In the Pan-African E-Commerce Initiative (Kenya, Rwanda, Ghana), evaluators found no significant increase in cross-border e-commerce despite strong policy outputs because of logistics bottlenecks (poor address systems, high cross-border transport costs), foreign exchange restrictions, and the absence of a pan-African mobile payment system. Even in countries with relatively good telecommunications infrastructure (Kenya, South Africa), e-commerce still played a minor role. Implication: proposals should either scope outcomes to national markets or budget for concrete enabling measures (payments interoperability, address systems, customs facilitation) before claiming cross-border sales outcomes. [Source: 2025-02_2019.2336.6_en.pdf, Page 21; 2025-02_2019.2336.6_en.pdf, Page 7]
#
# - Trust seals can shift consumer behavior when backed by credible certification and market-facing placement, but they do not substitute for customer retention and end-to-end service quality. In Rwanda, a trust seal managed by the Digital Business Institute (DBI) certified 13 platforms by 12/2022 (target 5), and later 29 by the time of the evaluation mission; companies and DBI reported sales increases linked to certification and observed higher consumer confidence when seals were prominently displayed. However, interviews stressed that a trust seal alone was insufficient without support on customer retention, post-training problem-solving, and comprehensive success measurement. Implication: bundle trust-building instruments with follow-on coaching, customer retention strategies, and complaint redress mechanisms; ensure a capable host institution and stable financing for certification and periodic re-audits. [Source: 2025-02_2019.2336.6_en.pdf, Page 43; 2025-02_2019.2336.6_en.pdf, Page 46; 2025-02_2019.2336.6_en.pdf, Page 62; 2025-02_2019.2336.6_en.pdf, Page 64]
#
# - SME training produced rapid adoption when paired with practical e-commerce setup support, yet benefits risk being short-lived without structured post-training pathways and funding for trainer cascades. In Kenya, more than 50% of participants established online businesses and actively marketed products post-training, with reported sales increases and operational improvements. Across countries, SMEs requested ongoing support, structured training progression, customer retention focus, and post-training troubleshooting. Training-of-trainers was recognized in Kenya and Rwanda, but lacked a plan or funding for local trainers to continue capacity building without external support; Ghana did not use ToT in this phase. Implication: plan for 6–12 months of post-training coaching, customer retention practices, and a financed ToT cascade embedded in host institutions. [Source: 2025-02_2019.2336.6_en.pdf, Page 62; 2025-02_2019.2336.6_en.pdf, Page 63]
#
# - Logistics-side interventions had measurable effects on SME operations and sales, but systemic postal/address constraints remained a binding barrier. Courier operator training (packaging, narcotics detection) improved vigilance against illicit trade, tax calculation, social security practices, food handling, and use of social media for regulatory purposes; SMEs adopting sustainable packaging saw positive customer responses and increased sales. Yet, postal reliability scores remained low (Kenya 27/100, Rwanda 30/100), and inadequate address systems and high transport costs continued to limit cross-border scaling. Implication: include logistics and last-mile components (address systems, courier capacity building, sustainable packaging, service-level standards) and do not assume postal reliability will improve without targeted measures. [Source: 2025-02_2019.2336.6_en.pdf, Page 21; 2025-02_2019.2336.6_en.pdf, Page 45; 2025-02_2019.2336.6_en.pdf, Page 62]
#
# - Participatory policy processes increased ownership but caused delays when institutional roles were not formalized early; project flexibility mitigated some risks by adding needed activities mid-course. The e-commerce strategies (Kenya, EAC) and e-payments blueprint (Ghana) benefited from government-private participation, fostering adoption, but delayed collaborations hindered integrating agencies’ contributions into design. Flexibility allowed the project to add activities such as an annual e-commerce cybersecurity forum with NITA. Implication: secure formal commitments, timelines, and responsibilities at the start; reserve budget and governance flexibility to add activities triggered by stakeholder cooperation needs. [Source: 2025-02_2019.2336.6_en.pdf, Page 64; 2025-02_2019.2336.6_en.pdf, Page 64; 2025-02_2019.2336.6_en.pdf, Page 64]
#
# Critical Success Factors:
# - Sequence enabling conditions before scaling cross-border outcomes:
#   - Payments interoperability and blueprint implementation agreements signed with timelines, operator roles, and contingency plans for system delays. [Source: 2025-02_2019.2336.6_en.pdf, Page 64]
#   - Logistics improvements: address system pilots, courier operator training, and packaging standards rolled out ahead of cross-border sales targets. [Source: 2025-02_2019.2336.6_en.pdf, Page 21; Page 45]
#
# - Institutionally anchored trust and training:
#   - Host an independent certifying body (e.g., DBI-type institute) with the mandate and resources to certify, monitor, and re-certify platforms; require prominent seal placement and consumer complaint redress. [Source: 2025-02_2019.2336.6_en.pdf, Page 46; Page 62]
#   - Design a financed training-of-trainers cascade and a structured post-training support pathway (coaching, troubleshooting, customer retention) for at least two quarters after training. [Source: 2025-02_2019.2336.6_en.pdf, Page 63; Page 62]
#
# - Early formalization and flexible delivery:
#   - Formalize stakeholder roles, deliverables, and timelines at project inception; include adaptive management provisions to add activities in response to collaboration gaps (e.g., cybersecurity forums). [Source: 2025-02_2019.2336.6_en.pdf, Page 64]
#
# - Realistic targeting and measurement:
#   - Set national market adoption targets first; tie cross-border targets to verified progress on payments/logistics. Use indicators that track sustained outcomes (e-commerce sales 1–2 quarters after training were tracked; extend to 12 months). [Source: 2025-02_2019.2336.6_en.pdf, Page 43; Page 7; Page 21]
#
# Common Failure Modes:
# - Strategy-output bias without execution capacity: e-payment blueprints and e-commerce strategies adopted but delayed implementation, resulting in limited benefits. Early warning sign: absence of named implementing operators, timelines, and risk mitigation for system delays. [Source: 2025-02_2019.2336.6_en.pdf, Page 64]
#
# - Overpromising on cross-border outcomes: claiming regional sales increases without tackling address systems, postal reliability, transport costs, and foreign exchange constraints. Early warning sign: reliance on mobile money for cross-border payments despite lack of pan-African interoperability. [Source: 2025-02_2019.2336.6_en.pdf, Page 21]
#
# - Trust-building as a standalone fix: deploying seals or labels without customer service/retention processes, complaint redress, and continuous support. Early warning sign: no budget line for post-training coaching or customer retention activities; seals not linked to performance monitoring. [Source: 2025-02_2019.2336.6_en.pdf, Page 62; Page 64]
#
# - Training drop-off due to missing sustainability mechanisms: ToT cohorts created but no plan or funding for them to keep delivering; gains fade as SMEs face post-training hurdles. Early warning sign: ToT strategy not embedded in an institution with an operating budget; Ghana phase did not consider ToT. [Source: 2025-02_2019.2336.6_en.pdf, Page 63]
#
# - Platform/network sustainability dependent on external support: business support platforms functioning only with continuous donor inputs, with insufficient technical capacity building for SMEs (structuring over skills). Early warning sign: platform governance optimized for coordination but weak market intelligence and technical support to SMEs. [Source: 2023-03_2016.2144.0_fr.pdf, Page 65; Page 61; Page 41]
#
# Red Flags for Proposal Review:
# - Cross-border sales targets not conditioned on:
#   - Payment system interoperability milestones and named operator commitments. [Source: 2025-02_2019.2336.6_en.pdf, Page 64]
#   - Logistics improvements (addressing system, courier capacity, packaging). [Source: 2025-02_2019.2336.6_en.pdf, Page 21; Page 45]
#
# - Trust-seal or certification elements without:
#   - A competent certifying institution, re-certification plan, consumer complaint redress, and public awareness. [Source: 2025-02_2019.2336.6_en.pdf, Page 46; Page 62]
#
# - Training components lacking:
#   - Funded post-training coaching for 6–12 months, customer retention support, clear monitoring of sustained sales outcomes, or a financed, institutionally embedded ToT. [Source: 2025-02_2019.2336.6_en.pdf, Page 62; Page 63; Page 43]
#
# - Stakeholder “engagement” described generically without formalized roles, timelines, and integration plan; evidence of prior delays or dependence on future modifications to add critical activities. [Source: 2025-02_2019.2336.6_en.pdf, Page 64]
#
# - Assumption that virtual matchmaking will substitute for market development: prior evidence indicates physical B2B interactions yield better results for SMEs, especially for product sampling and credibility, when organized centrally by trade representations. [Source: 2023-03_2016.2144.0_fr.pdf, Page 41]
#
# Evidence Gaps:
# - Quantitative attribution of sales uplift from trust seal certification over 12 months, beyond DBI’s post-launch survey; robust counterfactual data is limited. [Source: 2025-02_2019.2336.6_en.pdf, Page 46]
# - Detailed cost structures and sustainability plans for certifying institutions (e.g., DBI) to maintain and enforce trust seals long term. No evidence found in available documents for this claim.
# - Measured improvements in postal reliability or address systems linked to project interventions; the evaluation flags low scores but does not quantify project-induced changes. [Source: 2025-02_2019.2336.6_en.pdf, Page 21]
# - Disaggregated sectoral outcomes (which product categories or services gained most from training or trust seals) and long-term customer retention metrics. Insufficient evidence found in available documents.
# - Budget allocations for post-training coaching and ToT sustainability in future phases; while the project’s overall budget expanded from 4.6 million euros to 5.6 million euros when Ghana was added, detailed allocation to these mechanisms was not found. [Source: 2025-02_2019.2336.6_en.pdf, Page 20]
#
# ### Sources
# [1] Central project evaluation – Pan-African E-Commerce Initiative (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 21
# [2] Central project evaluation – Pan-African E-Commerce Initiative (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 7
# [3] Central project evaluation – Pan-African E-Commerce Initiative (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 43
# [4] Central project evaluation – Pan-African E-Commerce Initiative (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 46
# [5] Central project evaluation – Pan-African E-Commerce Initiative (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 62
# [6] Central project evaluation – Pan-African E-Commerce Initiative (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 64
# [7] Central project evaluation – Pan-African E-Commerce Initiative (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 63
# [8] Central project evaluation – Pan-African E-Commerce Initiative (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 45
# [9] Central project evaluation – Pan-African E-Commerce Initiative (2025-02) | 2025-02_2019.2336.6_en.pdf | Page 20
# [10] Africa, supraregional: Support of the Partnership Making Finance Work for Africa (MFW4A) – Project evaluation: summary report (2016-12) | 2016-12_2013.2019.1_en.pdf | Page 5
# [11] Évaluation centrale de projet – Promotion des activités d’export créatrices d’emploi vers de nouveaux marchés africains, Tunisie; Rapport d’évaluation (2023-03) | 2023-03_2016.2144.0_fr.pdf | Page 41
# [12] Évaluation centrale de projet – Promotion des activités d’export créatrices d’emploi vers de nouveaux marchés africains, Tunisie; Rapport d’évaluation (2023-03) | 2023-03_2016.2144.0_fr.pdf | Page 61
# [13] Évaluation centrale de projet – Promotion des activités d’export créatrices d’emploi vers de nouveaux marchés africains, Tunisie; Rapport d’évaluation (2023-03) | 2023-03_2016.2144.0_fr.pdf | Page 65
#
# ================================================================================
# RESEARCHING:
# ================================================================================
#
#
# ================================================================================
# RESEARCH QUESTION:
# ================================================================================
#
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
#
# To proceed, I need a few specifics about the proposed project you want critically reviewed. Please provide:
#
# - Sector and sub-sector (for example: rural water supply, off-grid energy mini-grids, climate-smart agriculture, TVET for green jobs, digital public services)
# - Country/region and whether it is fragile/conflict-affected or stable
# - Core objectives and target population (including gender/age and geographic focus)
# - Delivery approach (public sector, NGO, private, blended; centralized vs. decentralized)
# - Financing modality (grant, loan, results-based financing), indicative budget, and timeline
# - Key implementing partners and government counterparts (including which level of government)
# - Technology or intervention design choices already assumed (for example: prepaid meters, farmer field schools, e-procurement)
# - Sustainability plan (for example: user fee model, government budget allocation, private O&M concession)
# - Any specific questions or risks you want stress-tested (for example: maintenance viability, political buy-in, long-term outcomes, equity impacts)
#
# If helpful, I can immediately run an evidence analysis on one of these common project types:
# - Rural water supply with community management in the Sahel
# - Solar mini-grids for last-mile electrification in Southeast Asia
# - Climate-smart smallholder agriculture in East Africa
# - Skills and TVET for green jobs in North Africa
# - Digitalization of administrative services in West Africa
#
# Once you confirm the topic and details, I will:
# 1) Map the landscape (successes and failures) across similar projects.
# 2) Deep-dive into mechanisms, implementation details, budgets, and political economy.
# 3) Synthesize actionable, non-obvious insights with strict source citations and page numbers.
# 4) Flag red flags for proposal review and evidence gaps to address before approval.
#
# ================================================================================
# RESEARCHING:
# ================================================================================
#
#
# ================================================================================
# RESEARCH QUESTION:
# ================================================================================
#
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
#
# To proceed, I need to scope the research question. Please provide the following so I can run a targeted evidence review and extract non-obvious, actionable lessons:
#
# - Sector and approach: What type of project are you reviewing (e.g., rural mini-grids, fecal sludge management, climate-smart agriculture extension, TVET reform, social protection cash transfers, coastal resilience)? Specify key mechanisms (infrastructure build, training, policy reform, cash/credit, blended finance, digital systems).
# - Geography and level: Countries and (if relevant) subnational regions. Urban vs. rural; fragility context; key implementing institutions.
# - Proposal stage and decisions: What decisions you need to inform (go/no-go, design revisions, risk mitigation, budget reallocations, partner selection) and your timeline.
# - Comparator preferences: Any donors, programs, or timeframes you want prioritized (e.g., World Bank ICRs since 2015, EU evaluations, GIZ/USAID midterms, DFID/FCDO learning briefs).
# - Hypotheses to test: Specific claims in the proposal we should critically assess (e.g., “community O&M fees will cover 100% of maintenance,” “digital extension will reach women farmers,” “PPP will mobilize 3x private capital,” “results-based financing will improve service quality”).
# - Constraints: Budget bands, scale (pilot vs. national rollout), sustainability horizon (years post-closure), political economy sensitivities to consider.
# - Document access: If you have internal reports or country strategy notes to include, list filenames; otherwise I will rely on publicly available evaluations.
#
# If helpful, you can select one of these focus areas for a first rapid evidence pass:
# - Off-grid rural electrification mini-grids (Africa or South Asia)
# - Urban sanitation and fecal sludge management service chains (South Asia or West Africa)
# - Climate-smart agriculture extension and input subsidy reform (East or Southern Africa)
# - TVET and employment linkage programs (North Africa or Southeast Asia)
# - Mangrove/coastal resilience and community-based conservation (South and Southeast Asia)
# - Social protection cash transfers and delivery system strengthening (Latin America or Africa)
# - Digital public infrastructure for civil registration and social registry integration (multiple regions)
#
# Process I will follow once scoped:
# - Phase 1: Landscape mapping (deep_search) to identify comparable projects, successes, and failures.
# - Phase 2: Critical analysis (find_failure_cases, find_longterm_outcomes) to surface sustainability and post-project outcomes.
# - Phase 3: Evidence gathering (analyze_context_factors, find_implementation_details) for mechanisms, political economy, and budgets.
# - Phase 4: Risk assessment (identify_risk_patterns) to translate lessons into review red flags.
# - Output: Structured key findings with page-cited sources, critical success factors, failure modes, proposal red flags, and evidence gaps. All findings will note conditionality and flag single-source evidence.
#
# Once you confirm the scope, I will run up to four targeted searches and deliver the synthesis aligned to your decision needs.
